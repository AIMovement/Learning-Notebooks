# %% [markdown]
# # Transfer learning

# %% [markdown]
# Useful links:
# * https://machinelearningmastery.com/transfer-learning-for-deep-learning/
# * https://sefiks.com/2017/12/10/transfer-learning-in-keras-using-inception-v3/

# %% [markdown]
# _"Transfer learning is the improvement of learning in a new task through the transfer of knowledge from a related task that has already been learned."_

# %% [markdown]
# Commonly used in image analysis but also NLP. Three most common nets are InceptionNet, VGG and ResNEt.

# %%
from IPython.display import Image
Image("https://i2.wp.com/sefiks.com/wp-content/uploads/2017/12/imagenet-models.png")

# %% [markdown]
# ## A simple transfer learning implementation for image analysis
